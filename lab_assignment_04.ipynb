# %% [markdown]
# <a href="https://colab.research.google.com/github/AlekhyaPoreddy/Alekhya_INFO-5502/blob/main/lab_assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The fourth Lab-assignment (07/26/2022 11:59'AM' - 07/29/2022 11:59PM, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand Exploratory Data Analysis, we will practice the EDA by working on multiple datasets which have different characteristics.

# %% [markdown]
# Question 1 (10 points). Understand a text corpus for domain-specific text classification. Download the dataset from the following link: https://osf.io/8mjcy/ . Conduct EDA of the dataset from the following aspects:
#
# (1) How many categories in total?
#
# (2) How many documents under each category?

# %%
import zipfile
# opening the zip file in READ mode
with zipfile.ZipFile("/content/drive/MyDrive/preprocessed_cases[cases_29404].zip","r") as zip_ref:  
    # extracting all the files
    print('Extracting all the files now...')
    zip_ref.extractall("targetdir1")
    print('Done!')
# Out:
# Extracting all the files now...
# Done!

# %%
# Question 1) 
import os
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import PlaintextCorpusReader
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger') 

#1)
path = os.listdir("/content/targetdir1/preprocessed_cases[cases_29404]")
print('There are {} categories present'.format(len(path)))

#2)
for i in path:
  docs = os.listdir("/content/targetdir1/preprocessed_cases[cases_29404]/{}".format((i)))
  print('In each file# {} there are {} documents'.format(i,len(docs)))
# Out:
# There are 76 categories present
# In each file# 56 there are 395 documents
# In each file# 60 there are 42 documents
# In each file# 31 there are 516 documents
# In each file# 45 there are 1085 documents
# In each file# 5 there are 751 documents
# In each file# 54 there are 95 documents
# In each file# 16 there are 826 documents
# In each file# 6 there are 380 documents
# In each file# 21 there are 735 documents
# In each file# 34 there are 786 documents
# In each file# 53 there are 142 documents
# In each file# 28 there are 315 documents
# In each file# 36 there are 889 documents
# In each file# 19 there are 349 documents
# In each file# 71 there are 457 documents
# In each file# 3 there are 184 documents
# In each file# 44 there are 825 documents
# In each file# 55 there are 48 documents
# In each file# 1 there are 775 documents
# In each file# 2 there are 179 documents
# In each file# 33 there are 272 documents
# In each file# 66 there are 207 documents
# In each file# 22 there are 284 documents
# In each file# 20 there are 1129 documents
# In each file# 10 there are 584 documents
# In each file# 77 there are 146 documents
# In each file# 24 there are 628 documents
# In each file# 63 there are 194 documents
# In each file# 35 there are 68 documents
# In each file# 15 there are 257 documents
# In each file# 50 there are 68 documents
# In each file# 41 there are 1020 documents
# In each file# 73 there are 705 documents
# In each file# 25 there are 244 documents
# In each file# 74 there are 60 documents
# In each file# 7 there are 621 documents
# In each file# 37 there are 74 documents
# In each file# 9 there are 744 documents
# In each file# 13 there are 458 documents
# In each file# 42 there are 1292 documents
# In each file# 67 there are 356 documents
# In each file# 51 there are 225 documents
# In each file# 58 there are 150 documents
# In each file# 47 there are 151 documents
# In each file# 69 there are 700 documents
# In each file# 18 there are 509 documents
# In each file# 32 there are 118 documents
# In each file# 62 there are 218 documents
# In each file# 8 there are 521 documents
# In each file# 27 there are 77 documents
# In each file# 43 there are 234 documents
# In each file# 14 there are 277 documents
# In each file# 39 there are 261 documents
# In each file# 40 there are 510 documents
# In each file# 17 there are 125 documents
# In each file# 11 there are 605 documents
# In each file# 57 there are 108 documents
# In each file# 65 there are 276 documents
# In each file# 61 there are 181 documents
# In each file# 75 there are 473 documents
# In each file# 38 there are 503 documents
# In each file# 59 there are 51 documents
# In each file# 29 there are 213 documents
# In each file# 78 there are 242 documents
# In each file# 52 there are 318 documents
# In each file# 72 there are 74 documents
# In each file# 12 there are 275 documents
# In each file# 64 there are 130 documents
# In each file# 30 there are 881 documents
# In each file# 49 there are 17 documents
# In each file# 68 there are 263 documents
# In each file# 70 there are 192 documents
# In each file# 76 there are 177 documents
# In each file# 4 there are 231 documents
# In each file# 26 there are 754 documents
# In each file# 23 there are 179 documents
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# Question 2 (40 points). Continue practicing how to do simple exploratory data analysis with Python. The dataset that has been used in this question is called Student Academics Performance Data Set, which can be downloaded at: https://github.com/suthapalliuday/INFO5502-Summer2022/blob/main/datasets/lab-assignment-04-student-performance.csv . Please conduct the following analysis:
#
# (1) Description of all the columns: for each colmun, count number of rows, number of unqiue element, the frequency of each unqiue element.
#
#
# (2)  Visualize the count for each value in the 'Study Hours' column. Note: Study Hours values comes from this >= 6 hours Good >= 4 hours Average < 2 hours Poor.
#
# (3) Using factorplot to show the relationship between numerical and categorical value. Please use figure to show relation between [Study Hours] and [End Semester Percentage]. Percentage is calculated based on the following:
#
# if percentage >=80 then Best
# If percentage >= 60 but less than 80 then Very Good
# If percentage >= 45 but less than 60 then Good
# If Percentage >= 30 but less than 45 then Pass
# If Percentage < 30 then Fail
#
# (4) Get the correlation from the data, then plug it to heatmap function and show it as following:
#
# ![heatmap.png](attachment:heatmap.png)

# %% [markdown]
# # Your answer here (code + explanation):

# %%
# Question 2.1)
import pandas as pd
url = 'https://raw.githubusercontent.com/suthapalliuday/INFO5502-Summer2022/main/datasets/lab-assignment-04-student-performance.csv'
# reading raw data from git
df = pd.read_csv(url)
for col in df.columns:
    print("Column -",col)
    print("Number of rows -", df[col].shape[0])
    print("NUmber of unique values in this column -", df[col].value_counts().shape[0])
    print("Frequency of each element:")
    print(df[col].value_counts())
    print()
    print()
# Out:
# Column - ge
# Number of rows - 131
# NUmber of unique values in this column - 2
# Frequency of each element:
# M    72
# F    59
# Name: ge, dtype: int64
#
#
# Column - cst
# Number of rows - 131
# NUmber of unique values in this column - 5
# Frequency of each element:
# OBC     57
# G       44
# ST      20
# MOBC     6
# SC       4
# Name: cst, dtype: int64
#
#
# Column - tnp
# Number of rows - 131
# NUmber of unique values in this column - 4
# Frequency of each element:
# Good    59
# Vg      38
# Pass    25
# Best     9
# Name: tnp, dtype: int64
#
#
# Column - twp
# Number of rows - 131
# NUmber of unique values in this column - 4
# Frequency of each element:
# Good    65
# Vg      44
# Pass    17
# Best     5
# Name: twp, dtype: int64
#
#
# Column - iap
# Number of rows - 131
# NUmber of unique values in this column - 4
# Frequency of each element:
# Vg      63
# Good    53
# Best     8
# Pass     7
# Name: iap, dtype: int64
#
#
# Column - esp
# Number of rows - 131
# NUmber of unique values in this column - 4
# Frequency of each element:
# Good    54
# Vg      42
# Pass    27
# Best     8
# Name: esp, dtype: int64
#
#
# Column - arr
# Number of rows - 131
# NUmber of unique values in this column - 2
# Frequency of each element:
# N    78
# Y    53
# Name: arr, dtype: int64
#
#
# Column - ms
# Number of rows - 131
# NUmber of unique values in this column - 1
# Frequency of each element:
# Unmarried    131
# Name: ms, dtype: int64
#
#
# Column - ls
# Number of rows - 131
# NUmber of unique values in this column - 2
# Frequency of each element:
# V    92
# T    39
# Name: ls, dtype: int64
#
#
# Column - as
# Number of rows - 131
# NUmber of unique values in this column - 2
# Frequency of each element:
# Paid    76
# Free    55
# Name: as, dtype: int64
#
#
# Column - fmi
# Number of rows - 131
# NUmber of unique values in this column - 5
# Frequency of each element:
# Medium    63
# Am        27
# Low       20
# High      15
# Vh         6
# Name: fmi, dtype: int64
#
#
# Column - fs
# Number of rows - 131
# NUmber of unique values in this column - 3
# Frequency of each element:
# Small      89
# Average    40
# Large       2
# Name: fs, dtype: int64
#
#
# Column - fq
# Number of rows - 131
# NUmber of unique values in this column - 6
# Frequency of each element:
# Um        40
# 10        23
# 12        22
# Il        20
# Degree    20
# Pg         6
# Name: fq, dtype: int64
#
#
# Column - mq
# Number of rows - 131
# NUmber of unique values in this column - 6
# Frequency of each element:
# Um        52
# Il        27
# 10        25
# 12        17
# Degree     7
# Pg         3
# Name: mq, dtype: int64
#
#
# Column - fo
# Number of rows - 131
# NUmber of unique values in this column - 5
# Frequency of each element:
# Service     38
# Business    34
# Others      29
# Farmer      27
# Retired      3
# Name: fo, dtype: int64
#
#
# Column - mo
# Number of rows - 131
# NUmber of unique values in this column - 5
# Frequency of each element:
# Housewife    115
# Service       12
# Others         2
# Business       1
# Retired        1
# Name: mo, dtype: int64
#
#
# Column - nf
# Number of rows - 131
# NUmber of unique values in this column - 3
# Frequency of each element:
# Large      58
# Average    43
# Small      30
# Name: nf, dtype: int64
#
#
# Column - sh
# Number of rows - 131
# NUmber of unique values in this column - 3
# Frequency of each element:
# Average    59
# Poor       45
# Good       27
# Name: sh, dtype: int64
#
#
# Column - ss
# Number of rows - 131
# NUmber of unique values in this column - 2
# Frequency of each element:
# Govt       91
# Private    40
# Name: ss, dtype: int64
#
#
# Column - me
# Number of rows - 131
# NUmber of unique values in this column - 4
# Frequency of each element:
# Eng    62
# Asm    60
# Hin     7
# Ben     2
# Name: me, dtype: int64
#
#
# Column - tt
# Number of rows - 131
# NUmber of unique values in this column - 3
# Frequency of each element:
# Small      78
# Average    43
# Large      10
# Name: tt, dtype: int64
#
#
# Column - atd
# Number of rows - 131
# NUmber of unique values in this column - 3
# Frequency of each element:
# Good       56
# Average    47
# Poor       28
# Name: atd, dtype: int64

# %%
# Question 2.2)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
ax=sns.countplot(x='sh',data=df)
plt.rcParams['figure.figsize']=[10,10]
plt.xlabel("Study Hours")
plt.ylabel("No. of students")
plt.show()

# %%
# Question 2.3)
sns.catplot(x = "sh", y = "esp", data = df,kind="strip")
plt.xlabel("Study Hours")
plt.ylabel("End Semester Percentage")
plt.show()

# %%
# Question 2.4)
for x in df.columns:
    cat_columns = df.select_dtypes(['category']).columns
    df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)
    df[x] = df[x].astype('category')
corr=df.corr()

sns.set(rc={'figure.figsize':(30,15)})
sns.heatmap(corr,annot=True)
